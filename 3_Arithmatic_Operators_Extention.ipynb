# %% [markdown]
# <a href="https://colab.research.google.com/github/njElma/365-days-challenge-with-Python/blob/main/3_Arithmatic_Operators_Extention.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
a=645
m=987
q=a%m
print(q)
# Out:
# 645

# %%
a=2
p=2
w=a**p
print(w)
# Out:
# 4

# %%
45+65
# Out:
# 110

# %%
a=657
h=759
z=a/h
print(z)
# Out:
# 0.8656126482213439

# %%
print('A,B,C,D,E,F,G,H,I,J,K,L')
# Out:
# A,B,C,D,E,F,G,H,I,J,K,L

# %%
a=674
K=54
x=a%K
print(x)
# Out:
# 26

# %%
h=987
p=765
o=h%p
print(h)
# Out:
# 987

# %%
h=876
g=987
e=h//g
print(e)
# Out:
# 0

# %%
t=58
k=8
j=t**k
print(j)
# Out:
# 128063081718016

# %%
c=656
v=868
h=c//v
print(h)
# Out:
# 0

# %%
from os.path import join
v=7465
j=937
k=v%j
print(k)
# Out:
# 906
