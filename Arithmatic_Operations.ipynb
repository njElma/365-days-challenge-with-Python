# %% [markdown]
# <a href="https://colab.research.google.com/github/njElma/365-days-challenge-with-Python/blob/main/Arithmatic_Operations.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print(5+2)
# Out:
# 7

# %% [markdown]
# To add two values using varables

# %%
a=5
b=2
c=a+b
print(c)
# Out:
# 7

# %%
a=5
b=2
c=a-b
print(c)
# Out:
# 3

# %%
a=56
c=2
e=a/c
print(e)
# Out:
# 28.0

# %%
f=5436
a=5743
w=f*a
print(w)
# Out:
# 31218948

# %%
h=564870
f=874583
k=h*f
print(k)
# Out:
# 494025699210

# %%
e=3456
w=3467
s=465
d=94
p=e*w*s*d
print(p)
# Out:
# 523731121920

# %%
u=7486
j=9735
h=783
h=987
n=u*j/h+h
print(n)
# Out:
# 74823.07902735562

# %%
s=456
f=543
g=s*f
print(g)
# Out:
# 247608

# %%
473+7354
# Out:
# 7827
