# %% [markdown]
# <a href="https://colab.research.google.com/github/njElma/365-days-challenge-with-Python/blob/main/15_valid_or_not_valid_of_triangel's.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
a=float(input("Enter triangel's frist angel: "))
b=float(input("Enter triangel's secon angel:"))
c=float(input ("Enter triangel's thred angel:"))
d=a+b+c
print("d")
if 180==d:
 print("The angel are valid of triangel's")
else:
  print("The angel are not valid of triangel's")
# Out:
# Enter triangel's frist angel: 30
# Enter triangel's secon angel:60
# Enter triangel's thred angel:90
# d
# The angel are valid of triangel's
