# %% [markdown]
# <a href="https://colab.research.google.com/github/njElma/365-days-challenge-with-Python/blob/main/17_Counth_of_month.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
Days=float(input("Enter days:"))
if Days==31:
  print("It January,March,May,Julay,August,October,Desember")
elif Days==30:
  print("It April,June,Semtembr,November ")
else:
  print("It February")
# Out:
# Enter days:29
# It February
