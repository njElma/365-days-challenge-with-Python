# %% [markdown]
# <a href="https://colab.research.google.com/github/njElma/365-days-challenge-with-Python/blob/main/9_Find_Negative_and_Max_value.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Find Negative and Maxvalue

# %%
num1=float(input("Enter num1:"))
num2=float(input("Enter num2:"))
if num1<num2:
 print("num2 is bigger ")
else:
  print("num1 is bigger ")
# Out:
# Enter num1:6
# Enter num2:7
# num2 is bigger

# %%
num1=float(input("Enter num1:"))
if num1<0:
  print("The given number is negative")
else:
  print("The given number is positive")
# Out:
# Enter num1:-5
# The given number is negative
