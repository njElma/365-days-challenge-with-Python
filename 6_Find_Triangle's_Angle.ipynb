# %% [markdown]
# <a href="https://colab.research.google.com/github/njElma/365-days-challenge-with-Python/blob/main/6_Find_Triangle's_Angle.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Write a Python Program to input two angles from user and find third angle of the triangle.

# %%
a=float(input("Enter triangle's first angle:"))
b=float(input("Enter triangle's second angle:"))
c=180-(a+b)
print("The third angle is:", c)
# Out:
# Enter triangle's first angle:45
# Enter triangle's second angle:30
# The third angle is: 105.0
