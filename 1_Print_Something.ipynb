# %% [markdown]
# <a href="https://colab.research.google.com/github/njElma/365-days-challenge-with-Python/blob/main/1_Print_Something.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print('I am Elma. My cat name is Hany.\nHello Elma.How are you? ')
print('I eat rice.\nI am 10 years Old.')
print('My cat name is Hany.His fathers name is Modhu.His mothers name is Misty.There are six members in his family.He have 4 borthers and \nhis borthers names are Hany ,Bany,Jorder.Poppet. ')
# Out:
# I am Elma. My cat name is Hany.
# Hello Elma.How are you?
# I eat rice.
# I am 10 years Old.
# My cat name is Hany.His fathers name is Modhu.His mothers name is Misty.There are six members in his family.He have 4 borthers and
# his borthers names are Hany ,Bany,Jorder.Poppet.
