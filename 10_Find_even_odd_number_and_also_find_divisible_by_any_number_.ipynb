# %% [markdown]
# <a href="https://colab.research.google.com/github/njElma/365-days-challenge-with-Python/blob/main/10_Find_even_odd_number_and_also_find_divisible_by_any_number_.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Divisible by three

# %%
num1=float(input("Enter num1:"))
if num1%3==0:
  print("The number is divisible by three")
else:
  print("The number is not dvisible by three ")
# Out:
# Enter num1:5
# The number is not dvisible by three

# %% [markdown]
# # Dvisible by 5 and 11

# %%
num1=float(input("Enter num1:"))
if num1%5==0 and num1%11==0:
  print("The number is divisible by both of 5 and 11")
else:
  print("The number is not divisible by both of 5 and 11 ")
# Out:
# Enter num1:55
# The number is divisible by both of 5 and 11

# %% [markdown]
# # Even odd number

# %%
num1=float(input("Enter num1:"))
if num1%2==0:
 print("The number is even")
else:
  print("The number is odd")
# Out:
# Enter num1:8
# The number is even
