# %% [markdown]
# <a href="https://colab.research.google.com/github/njElma/365-days-challenge-with-Python/blob/main/7_Area_of_Trapezium.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Area of trapezium
# # area=((a+b)*h)/2

# %%
a=float(input("a:"))
b=float(input("b:"))
h=float(input("h:"))
area=((a+b)*h)/2
print("area:", area)
# Out:
# a:6
# b:6
# h:6
# area: 36.0
