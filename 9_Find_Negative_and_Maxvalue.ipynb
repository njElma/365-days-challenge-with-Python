# %% [markdown]
# <a href="https://colab.research.google.com/github/njElma/365-days-challenge-with-Python/blob/main/9_Find_Negative_and_Maxvalue.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Find Negative and Maxvalue

# %%
a=float(input("Enter num1:"))
b=float(input("Enter num2:"))
if a<b:
 print("num2 to is bigger ")
else:
  print("num1")
# Out:
# Enter num1:7
# Enter num2:6
# num1

# %%
a=float(input("Enter num1:"))
b=float(input("Enter num2:"))
if a>b:
  print("num1 to is bigger")
else:
  print("num2")
# Out:
# Enter num1:45
# Enter num2:67
# num2
