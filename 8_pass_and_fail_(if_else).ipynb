# %% [markdown]
# <a href="https://colab.research.google.com/github/njElma/365-days-challenge-with-Python/blob/main/8_pass_and_fail_(if_else).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
marks=float(input("Enter marks:"))
if marks<33 :
 print("fail")
else:
  print("pass")
# Out:
# Enter marks:68
# pass

# %%
marks=float(input("Enter marks:"))
if marks>=33:
  print("Pass")
else:
   print("Fail")
# Out:
# Enter marks:33
# Pass
