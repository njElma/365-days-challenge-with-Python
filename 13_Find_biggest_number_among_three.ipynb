# %% [markdown]
# <a href="https://colab.research.google.com/github/njElma/365-days-challenge-with-Python/blob/main/13_Find_biggest_number_among_three.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
num1=float(input("Enter num1:"))
num2=float(input("Enter num2:"))
num3=float(input("Enter num3:"))
if num1> num2 and num1>num3:
 print("num1 is the biggest number")
elif num2>num1 and num2>num3:
  print("num2 is the biggest number")
else:
  print("num3 is the biggest number")
# Out:
# Enter num1:56
# Enter num2:78
# Enter num3:87
# num3 is the biggest number
