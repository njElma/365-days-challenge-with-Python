# %% [markdown]
# <a href="https://colab.research.google.com/github/njElma/365-days-challenge-with-Python/blob/main/14_Leap_year.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
year=float(input("Enter year:"))
if year%400==0 or year%4==0:
  print("The year is leap year")
else:
  print("The year is not leap year")
# Out:
# Enter year:1800
# The year is leap year
