# %% [markdown]
# <a href="https://colab.research.google.com/github/njElma/365-days-challenge-with-Python/blob/main/11_12_Types_alphabet.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
ch=input("Enter character:")
if ch=='a' or ch=='i' or ch=='e' or ch=='o' or ch=='u':
 print("The character is vowel")
else:
  print("The character is consonant")
# Out:
# Enter character:u
# The character is vowel

# %%
ch=input("Enter character:")
if ch>='a' and ch<='z':
  print("small alphabet")
elif ch>='A' and ch<='Z':
  print("capital alphabet")
# Out:
# Enter character:F
# capital alphabet
